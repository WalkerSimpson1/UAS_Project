# %%
import os
import time
import requests
import pandas as pd
from datetime import date
from dotenv import load_dotenv

load_dotenv() 
print ("Libraries imported")
# Out:
# Libraries imported

# %%
API_KEY = os.getenv("LEGI_API_KEY")

# %%
url = "https://api.legiscan.com/?key=ab3b284279ed5251a660ee24f024dc51&op=getDatasetRaw&access_key=5Nv0jmvvpJya6F4uF665wx&id=2237&format=csv"
